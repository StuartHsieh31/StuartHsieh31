# %% [markdown]
# <a href="https://colab.research.google.com/github/StuartHsieh31/StuartHsieh31/blob/main/Copy_of_Yolov4_6_class_material_which_is_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# Step 2

# %%
! git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15376, done.
# remote: Total 15376 (delta 0), reused 0 (delta 0), pack-reused 15376
# Receiving objects: 100% (15376/15376), 14.01 MiB | 18.11 MiB/s, done.
# Resolving deltas: 100% (10340/10340), done.

# %% [markdown]
# Step 3 5

# %%
# !head darknet/Makefile
# Out:
# GPU=0
# CUDNN=0
# CUDNN_HALF=0
# OPENCV=0
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %% [markdown]
# Step 4

# %%
! sed -i "s/GPU=0/GPU=1/g" /content/darknet/Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" /content/darknet/Makefile
! sed -i "s/OPENCV=0/OPENCV=1/g" /content/darknet/Makefile

# %% [markdown]
# Train with cpu and also Change mosaic : form one to zero in line 26 at file yolov4-obj.cfg.

# %%
! sed -i "s/GPU=1/GPU=0/g" /content/darknet/Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" /content/darknet/Makefile
! sed -i "s/OPENCV=1/OPENCV=0/g" /content/darknet/Makefile

# %% [markdown]
# Step 6

# %%
! cd darknet; make

# %% [markdown]
# Step 7 - download weights

# %%
! gdown https://drive.google.com/uc?id=1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT
# To: /content/yolov4.weights
# 100% 258M/258M [00:02<00:00, 109MB/s]

# %% [markdown]
# Step 8 - detect

# %%
! ls darknet/data
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   person.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  scream.jpg
# coco.names  goal.txt	 labels			   voc.names
# dog.jpg     horses.jpg	 openimages.names

# %% [markdown]
# 先看圖，還未辨識。

# %%
from PIL import Image
Image.open("darknet/data/dog.jpg")

# %%
! cd darknet; ./darknet detect /content/darknet/cfg/yolov4.cfg  /content/yolov4.weights /content/darknet/data/dog.jpg

# %%
Image.open("/content/darknet/predictions.jpg")

# %% [markdown]
# Step 9

# %%
! cd darknet; ./darknet detector test /content/darknet/cfg/coco.data /content/darknet/cfg/yolov4.cfg  /content/yolov4.weights  /content/darknet/data/person.jpg

# %%
! cd darknet; ./darknet detector demo /content/darknet/cfg/coco.data /content/darknet/cfg/yolov4.cfg /content/yolov4.weights –dont_show /content/test.mp4 -i 0 -out_filename /content/results.avi

# %% [markdown]
# Step 1

# %% [markdown]
# HW

# %%
#%cd drive/mydrive/
# Out:
# [Errno 2] No such file or directory: 'drive/mydrive/'
# /content

# %%
#!ls /content/drive/MyDrive/yolov4
# Out:
# 'Copy of Yolov4_6-class material'   obj.zip   test.zip

# %%
#!cp /MyDrive/yolov4/obj.zip../
#!cp /content/drive/MyDrive/yolov4/test.zip -d content/
# Out:
# cp: missing destination file operand after '/MyDrive/yolov4/obj.zip../'
# Try 'cp --help' for more information.

# %%
# !unzip /content/drive/MyDrive/yolov4/obj.zip -d darknet/data/

# %%
# !unzip /content/drive/MyDrive/yolov4/test.zip -d darknet/data/

# %% [markdown]
# Step 2

# %%
# %cd /content/darknet
# !pwd
# Out:
# /content/darknet
# /content/darknet

# %%
# !cp /content/drive/MyDrive/yolov4/obj.data ./data
# !cp /content/drive/MyDrive/yolov4/obj.names.txt ./data
# !cp /content/drive/MyDrive/yolov4/obj.names ./data
# !cp /content/drive/MyDrive/yolov4/yolov4-obj.cfg ./

# %%
# !cp /content/drive/MyDrive/yolov4/generate_train.py ./darknet
# !cp /content/drive/MyDrive/yolov4/generate_test.py ./darknet

# %%
# !python generate_train.py
# !python generate_test.py

# %%
# !ls data/
# Out:
# 9k.tree      goal.txt		       obj.data		 test
# coco9k.map   horses.jpg		       obj.names	 test.txt
# coco.names   imagenet.labels.list      obj.names.txt	 train.txt
# dog.jpg      imagenet.shortnames.list  openimages.names  voc.names
# eagle.jpg    labels		       person.jpg
# giraffe.jpg  obj		       scream.jpg

# %% [markdown]
# Step 3

# %%
# !pwd
# Out:
# /content/darknet

# %%
#!wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# !./darknet detector train data/obj.data /content/drive/MyDrive/yolov4/yolov4-obj.cfg /content/drive/MyDrive/yolov4/backup/yolov4-obj_last.weights -dont_show –map
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.877533), count: 9, class_loss = 0.003943, iou_loss = 0.276772, total_loss = 0.280716
#  total_bbox = 249307, rewritten_bbox = 0.409134 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.772028), count: 69, class_loss = 2.227916, iou_loss = 341.796295, total_loss = 344.024200
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.866830), count: 15, class_loss = 0.064535, iou_loss = 5.863743, total_loss = 5.928277
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.879634), count: 17, class_loss = 0.004738, iou_loss = 0.870891, total_loss = 0.875629
#  total_bbox = 249408, rewritten_bbox = 0.408968 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.867542), count: 5, class_loss = 0.000321, iou_loss = 11.550454, total_loss = 11.550776
# ...

# %%
# show chart.png of how custom object detector did
# with training
imShow('chart.png')

# %%
#kick off
# !./darknet detector train data/obj.data /content/drive/MyDrive/yolov4/yolov4-obj.cfg /content/drive/MyDrive/yolov4/backup/yolov4-obj_last.weights -dont_show

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !./darknet detector map data/obj.data /content/drive/MyDrive/yolov4/yolov4-obj.cfg /content/drive/MyDrive/yolov4/backup/yolov4-obj_final.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 4, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
# !pwd
# Out:
# /

# %%
# need to set our custom cfg to test mode

# %cd cfg
# !sed -i 's/batch=16/batch=1/' yolov4-obj.cfg
# !sed -i 's/subdivisions=4/subdivisions=1/' yolov4-obj.cfg
# %cd ..
# Out:
# /content/darknet/cfg
# /content/darknet

# %%
#%cd /content/darknet
#!pwd
# Out:
# /content/darknet
# /content/darknet

# %%
#!cp /content/drive/MyDrive/yolov4/yolov4-obj.cfg ./cfg
#!cp /content/drive/MyDrive/yolov4/yolov4-obj.cfg ./data

# %%
# !cp /content/drive/MyDrive/fly.mp4 ./

# %%
# run your custom detector with this command (upload a video to your google drive to
#test, thresh flag #sets accuracy that detection must be in order to show it)

# !./darknet detector demo data/obj.data cfg/yolov4-obj.cfg /content/drive/MyDrive/yolov4/backup/yolov4-obj_final.weights –dont_show /content/fly.mp4 -thresh 0.3 -i 0 -out_filename /content/results.avi
# Out:
# /bin/bash: ./darknet: No such file or directory
